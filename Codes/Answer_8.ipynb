# %% [markdown]
# ### Importing libraries that will be useful :-

# %%
import warnings 
warnings.filterwarnings('ignore')
import json
import pandas as pd

# %% [markdown]
# # Question 8 solution :

# %% [markdown]
# Reading data from DDW_PCA0000_2011_Indiastatedist.xlsx file i.e population data :-

# %%
population_data= pd.read_excel('DDW_PCA0000_2011_Indiastatedist.xlsx',usecols=['Level','Name','TRU','TOT_P'])
# population_data
census_data_district = population_data.loc[(population_data['Level'] == 'DISTRICT') & (population_data['TRU'] == 'Total')]
census_data_district = census_data_district.drop(columns=["TRU"])
census_data_district["Name"] = census_data_district["Name"].str.lower()
census_data_district = census_data_district.sort_values('Name',ignore_index=True)
# len(census_data_district) is 640
# census_data_district

# %% [markdown]
# Reading data from cowin_vaccine_data_districtwise.csv file i.e vaccine data for each district :-

# %%
vaccine_data = pd.read_csv("cowin_vaccine_data_districtwise.csv",usecols=['State','District_Key','District',
                                                                '31/08/2021.3','31/08/2021.4'])
vaccine_data.rename(columns = {'31/08/2021.3':'First Dose Administered',
                               '31/08/2021.4':'Second Dose Administered'}, inplace = True)
vaccine_data = vaccine_data.drop(vaccine_data.index[0])

## Making all the district names into small letters so that merging will be easy ##
vaccine_data["District"] = vaccine_data["District"].str.lower()

## Changing vaccination numbers values type from object to numeric ##
vaccine_data['First Dose Administered'] = vaccine_data['First Dose Administered'].astype(float)
vaccine_data['Second Dose Administered'] = vaccine_data['Second Dose Administered'].astype(float)

## Sorting vaccination data on the basic of district values ##
vaccine_data = vaccine_data.sort_values('District',ignore_index=True)
# vaccine_data

# %% [markdown]
# So while printing "vaccine_data" we came to know that in vaccination data many districts are splitted into 2 or more parts. In order to avoid any confusion further while merging vaccination data with census data, lets merge them now (i.e. splitted districts)..

# %%
vaccine_data = vaccine_data.groupby(['State','District_Key','District']).agg({'First Dose Administered':'sum','Second Dose Administered':'sum'}).reset_index()  
vaccine_data = vaccine_data.sort_values('District',ignore_index=True)
# len(vaccine_data) is 729
# vaccine_data

# %% [markdown]
# While solving Q6 we came to know that many district names were changed or their spelling has been changed in vaccine data as compared to census data, So we found all such mismatching districts, now lets make a dictionary with key as district's wrong spelling and value as its correct spelling.

# %%
corrected_districts = {}
corrected_districts['aizwal']='aizawl'
corrected_districts['anugul']='angul'
corrected_districts['ashok nagar']='ashoknagar'
corrected_districts['badgam']='budgam'
corrected_districts['baleshwar']='balasore'
corrected_districts['banas kantha']='banaskantha'
corrected_districts['bangalore rural']='bengaluru rural'
corrected_districts['bangalore urban']='bengaluru urban'
corrected_districts['baramula']='baramulla'
corrected_districts['baudh']='boudh'
corrected_districts['belgaum']='belagavi'
corrected_districts['bellary']='ballari'
corrected_districts['bemetara']='bametara'
corrected_districts['bid']='beed'
corrected_districts['bishwanath']='biswanath'
corrected_districts['chamarajanagar']='chamarajanagara'
corrected_districts['dantewada']='dakshin bastar dantewada'
corrected_districts['debagarh']='deogarh' 
corrected_districts['devbhumi dwaraka']='devbhumi dwarka'
corrected_districts['dhaulpur']='dholpur'
corrected_districts['east karbi anglong']='karbi anglong'
corrected_districts['faizabad']='ayodhya'
corrected_districts['fategarh sahib']='fatehgarh sahib'
corrected_districts['firozpur']='ferozepur'
corrected_districts['gondiya']='gondia'
corrected_districts['hugli']='hooghly'
corrected_districts['jagatsinghapur']='jagatsinghpur'
corrected_districts['jajapur']='jajpur'
corrected_districts['jalor']='jalore'
corrected_districts['jhunjhunun']='jhunjhunu'
corrected_districts['jyotiba phule nagar']='amroha'
corrected_districts['kabirdham']='kabeerdham'
corrected_districts['kaimur (bhabua)']='kaimur'
corrected_districts['kanchipuram']='kancheepuram'
corrected_districts['kheri']='lakhimpur kheri'
corrected_districts['kochbihar']='cooch behar'
corrected_districts['kodarma']='koderma'
corrected_districts['komram bheem']='komaram bheem'
corrected_districts['lahul and spiti']='lahaul and spiti'
corrected_districts['mahesana']='mehsana'
corrected_districts['mahrajganj']='maharajganj'
corrected_districts['maldah']='malda'
corrected_districts['marigaon']='morigaon'
corrected_districts['muktsar']='sri muktsar sahib'
corrected_districts['mumbai city']='mumbai'
corrected_districts['nandubar']='nandurbar'
corrected_districts['narsimhapur']='narsinghpur'
corrected_districts['nav sari']='navsari'
corrected_districts['pakaur']='pakur'
corrected_districts['palghat']='palakkad'
corrected_districts['panch mahal']='panchmahal'
corrected_districts['pashchim champaran']='west champaran'
corrected_districts['pashchimi singhbhum']='west singhbhum'
corrected_districts['pattanamtitta']='pathanamthitta'
corrected_districts['purba champaran']='east champaran'
corrected_districts['purbi singhbhum']='east singhbhum'
corrected_districts['puruliya']='purulia'
corrected_districts['rae bareilly']='rae bareli'
corrected_districts['rajauri']='rajouri'
corrected_districts['rangareddy']='ranga reddy'
corrected_districts['ri-bhoi']='ribhoi'
corrected_districts['sabar kantha']='sabarkantha'
corrected_districts['sahibzada ajit singh nagar']='s.a.s. nagar'
corrected_districts['sait kibir nagar']='sant kabir nagar'
corrected_districts['sant ravidas nagar']='bhadohi'
corrected_districts['sepahijala']='sipahijala'
corrected_districts['seraikela kharsawan']='saraikela-kharsawan'
corrected_districts['shaheed bhagat singh nagar']='shahid bhagat singh nagar'
corrected_districts['sharawasti']='shrawasti'
corrected_districts['shimoga']='shivamogga'
corrected_districts['shopian']='shopiyan'
corrected_districts['siddharth nagar']='siddharthnagar'
corrected_districts['sivagangai']='sivaganga'
corrected_districts['sonapur']='subarnapur'
corrected_districts['south salmara-mankachar']='south salmara mankachar'
corrected_districts['sri ganganagar']='ganganagar'
corrected_districts['sri potti sriramulu nellore']='s.p.s. nellore'
corrected_districts['the dangs']='dang'
corrected_districts['the nilgiris']='nilgiris'
corrected_districts['thoothukudi']='thoothukkudi'
corrected_districts['tiruchchirappalli']='tiruchirappalli'
corrected_districts['tirunelveli kattabo']='tirunelveli'
corrected_districts['tiruvanamalai']='tiruvannamalai'
corrected_districts['tumkur']='tumakuru'
corrected_districts['yadagiri']='yadgir'
corrected_districts['ysr']='y.s.r. kadapa'

# len(corrected_districts) # = 71
# corrected_districts

# %% [markdown]
# So now lets correct all the wrong spellings of districts in census data.

# %%
for i in census_data_district.index:
    a = ''
    a = census_data_district.iloc[i]['Name']
    census_data_district.at[i, 'Name'] = corrected_districts.get(a, a)
# census_data_district

# %% [markdown]
# Merging vaccination data and census data side by side to calculate ratios easily :-

# %%
census_data_district['Name'] = census_data_district['Name'].str.strip()
vaccine_data['District'] = vaccine_data['District'].str.strip()
data_sample = pd.merge(vaccine_data,census_data_district,left_on='District', right_on='Name')
data_sample = data_sample.drop(columns=["Level","Name"])
# data_sample

# %% [markdown]
# Since in many states there are some distrits with same names so while merging they created some redundant rows which are incorrect, we found all of them by seeing manually. So now deleting those rows and re-setting index.
# ____Redundant rows are 30,31,81,217,218,450,451 and 466___

# %%
to_del = [30,31,81,217,218,450,451,466]
Final_data = data_sample.drop(data_sample.index[to_del])
Final_data = Final_data.reset_index()
Final_data = Final_data.drop(columns=["index"])
# len(Final_data) is 630
# Final_data

# %% [markdown]
# Now as we have merged, cleaned and pre-processed data so now it is ready for calculating ratios :-

# %% [markdown]
# ## Calculating ratios at district level :-

# %%
district_wise_data = Final_data.copy()
district_wise_data = district_wise_data.drop(columns=["District"])
district_wise_data.rename(columns = {'Male(Individuals Vaccinated)':'Males_Vaccinated',
                               'Female(Individuals Vaccinated)':'Females_Vaccinated',
                                 'District_Key':'districtid'}, inplace = True)
# district_wise_data

# %%
district_wise_data['vaccinateddose1ratio'] = district_wise_data['First Dose Administered']/district_wise_data['TOT_P']
district_wise_data['vaccinateddose2ratio'] = district_wise_data['Second Dose Administered']/district_wise_data['TOT_P']
district_wise_data = district_wise_data.drop(columns=["State","First Dose Administered","Second Dose Administered","TOT_P"])
district_wise_data = district_wise_data.sort_values('vaccinateddose1ratio',ignore_index=True)

# %%
with pd.option_context('display.max_rows', None,'display.max_columns', None,'display.precision', 4,):
    display(district_wise_data)
# district_wise_data
# Out:
#                        districtid  vaccinateddose1ratio  vaccinateddose2ratio
# 0                     TG_Adilabad                0.0419                0.0132
# 1                     MN_Senapati                0.0539                0.0135
# 2                        TG_Medak                0.0657                0.0206
# 3                 TN_Kancheepuram                0.0893                0.0167
# 4                    CT_Balrampur                0.0924                0.0201
# 5                 AR_Kurung Kumey                0.0942                0.0356
# 6                       MN_Ukhrul                0.1067                0.0428
# 7                     TG_Nalgonda                0.1068                0.0251
# 8                     HP_Bilaspur                0.1176                0.0414
# 9                   TG_Karimnagar                0.1176                0.0474
# 10                     TN_Vellore                0.1181                0.0370
# 11                   PB_Ferozepur                0.1242                0.0300
# 12                  MN_Tamenglong                0.1353                0.0407
# 13             ML_East Garo Hills                0.1394                0.0385
# 14              TG_Warangal Urban                0.1422                0.0428
# 15                 TN_Tirunelveli                0.1446                0.0338
# 16                     CT_Surguja                0.1456                0.0473
# 17                   TG_Nizamabad                0.1558                0.0494
# 18                  WB_Jalpaiguri                0.1562                0.0512
# 19                  TN_Viluppuram                0.1568                0.0278
# 20                     NL_Kiphire                0.1675                0.0552
# 21                   UP_Sultanpur                0.1756                0.0350
# 22                   UP_Moradabad                0.1756                0.0415
# 23                     TG_Khammam                0.1762                0.0409
# 24                     MN_Chandel                0.1778                0.0616
# 25                    NL_Tuensang                0.1782                0.0591
# 26                        NL_Phek                0.1822                0.0676
# 27               AS_Karbi Anglong                0.1832                0.0475
# 28            ML_West Khasi Hills                0.1856                0.0711
# 29           WB_Paschim Medinipur                0.1887                0.0787
# 30                       NL_Peren                0.1905                0.0728
# 31                       AR_Lohit                0.1991                0.0530
# 32                       NL_Wokha                0.2013                0.0842
# 33          ML_West Jaintia Hills                0.2018                0.0648
# 34                      CT_Bastar                0.2019                0.0591
# 35                      UP_Budaun                0.2024                0.0336
# 36                        CT_Durg                0.2035                0.0955
# 37                 WB_Cooch Behar                0.2082                0.0925
# 38               UP_Muzaffarnagar                0.2099                0.0366
# 39                  UP_Rae Bareli                0.2113                0.0274
# 40                       WB_Malda                0.2141                0.0827
# 41              WB_Uttar Dinajpur                0.2149                0.0726
# 42    CT_Dakshin Bastar Dantewada                0.2190                0.0757
# 43                 WB_Murshidabad                0.2196                0.0830
# 44                      MH_Nanded                0.2243                0.0791
# 45                 TN_Thiruvallur                0.2286                0.0603
# 46                     MH_Jalgaon                0.2290                0.0856
# 47                     WB_Purulia                0.2303                0.0902
# 48                     MH_Solapur                0.2356                0.0912
# 49                      AS_Dhubri                0.2374                0.0433
# 50                     PB_Sangrur                0.2394                0.0649
# 51                   UP_Prayagraj                0.2400                0.0624
# 52                      UP_Ballia                0.2403                0.0434
# 53                       PB_Mansa                0.2411                0.0575
# 54                   UP_Sonbhadra                0.2415                0.0477
# 55                      UP_Rampur                0.2421                0.0416
# 56                       WB_Nadia                0.2423                0.0992
# 57                    CT_Bilaspur                0.2447                0.0905
# 58                     UP_Sitapur                0.2471                0.0360
# 59             UP_Lakhimpur Kheri                0.2477                0.0285
# 60                     MH_Hingoli                0.2484                0.0703
# 61                   UP_Kaushambi                0.2489                0.0441
# 62            ML_South Garo Hills                0.2539                0.0799
# 63                  BR_Kishanganj                0.2558                0.0383
# 64                  CT_Narayanpur                0.2568                0.0905
# 65                      JH_Garhwa                0.2570                0.0547
# 66                   NL_Zunheboto                0.2573                0.0628
# 67            UP_Sant Kabir Nagar                0.2574                0.0385
# 68                      BR_Araria                0.2585                0.0477
# 69                 UP_Maharajganj                0.2594                0.0433
# 70                   JH_Sahibganj                0.2610                0.0461
# 71                   UP_Firozabad                0.2616                0.0448
# 72                      BR_Supaul                0.2623                0.0482
# 73                   BR_Madhepura                0.2623                0.0448
# 74                     BR_Katihar                0.2626                0.0379
# 75                  UP_Pratapgarh                0.2631                0.0388
# 76              BR_West Champaran                0.2633                0.0342
# 77                         NL_Mon                0.2645                0.0911
# 78                     JH_Dhanbad                0.2654                0.0878
# 79                  UP_Kushinagar                0.2666                0.0474
# 80                     UP_Aligarh                0.2676                0.0538
# 81                      BR_Kaimur                0.2684                0.0383
# 82                   MH_Osmanabad                0.2684                0.1036
# 83                        UP_Etah                0.2686                0.0368
# 84                   BR_Gopalganj                0.2687                0.0462
# 85                    UP_Mainpuri                0.2689                0.0358
# 86                   BR_Sitamarhi                0.2701                0.0440
# 87                   TN_Cuddalore                0.2707                0.0565
# 88                  MH_Ahmednagar                0.2708                0.1070
# 89                       UP_Unnao                0.2715                0.0439
# 90                       MH_Akola                0.2718                0.1126
# 91                      JH_Bokaro                0.2719                0.0804
# 92            DL_North East Delhi                0.2725                0.0859
# 93                     UP_Kasganj                0.2729                0.0360
# 94                UP_Shahjahanpur                0.2731                0.0442
# 95                       AR_Tirap                0.2735                0.0613
# 96                   PB_Gurdaspur                0.2748                0.1042
# 97                 UP_Farrukhabad                0.2757                0.0402
# 98                 AR_East Kameng                0.2757                0.1020
# 99                    PB_Bathinda                0.2766                0.0808
# 100                     AS_Nagaon                0.2768                0.0555
# 101                 BR_Aurangabad                0.2779                0.0369
# 102                    BR_Saharsa                0.2783                0.0536
# 103                     BR_Nawada                0.2793                0.0453
# 104                   MH_Amravati                0.2794                0.1090
# 105                  BR_Madhubani                0.2796                0.0536
# 106                    WB_Bankura                0.2798                0.1070
# 107                   BR_Khagaria                0.2802                0.0430
# 108                BR_Muzaffarpur                0.2804                0.0520
# 109                        UP_Mau                0.2806                0.0506
# 110                       MH_Beed                0.2807                0.0929
# 111             UP_Ambedkar Nagar                0.2813                0.0404
# 112                     UP_Hardoi                0.2819                0.0304
# 113                 BR_Lakhisarai                0.2825                0.0431
# 114                    JH_Giridih                0.2825                0.0501
# 115                       BR_Gaya                0.2836                0.0541
# 116                  UP_Chandauli                0.2851                0.0366
# 117                     UP_Deoria                0.2852                0.0527
# 118                   MH_Yavatmal                0.2855                0.0972
# 119               TN_Thoothukkudi                0.2857                0.0669
# 120                    JH_Latehar                0.2858                0.0577
# 121                    BR_Bhojpur                0.2861                0.0479
# 122                   BR_Vaishali                0.2864                0.0489
# 123                     UP_Amroha                0.2865                0.0472
# 124            AR_Upper Subansiri                0.2865                0.1085
# 125                      MH_Latur                0.2877                0.1031
# 126                      BR_Jamui                0.2877                0.0425
# 127                   MH_Parbhani                0.2881                0.1027
# 128                   TN_Ariyalur                0.2888                0.0597
# 129                     BR_Rohtas                0.2890                0.0508
# 130             JH_West Singhbhum                0.2892                0.0667
# 131                  MH_Nandurbar                0.2894                0.0947
# 132                 BR_Samastipur                0.2901                0.0518
# 133                     UP_Etawah                0.2901                0.0489
# 134                     CT_Koriya                0.2909                0.0828
# 135               UP_Kanpur Dehat                0.2910                0.0411
# 136                   MH_Buldhana                0.2913                0.1101
# 137                    UP_Kannauj                0.2929                0.0296
# 138                 AR_West Siang                0.2930                0.1228
# 139                 OR_Mayurbhanj                0.2932                0.0711
# 140                    UP_Auraiya                0.2943                0.0441
# 141                    UP_Jaunpur                0.2948                0.0496
# 142                    UP_Ayodhya                0.2948                0.0605
# 143                  TN_Thanjavur                0.2951                0.0553
# 144                    JH_Deoghar                0.2952                0.0671
# 145                   UP_Azamgarh                0.2965                0.0464
# 146                   PB_Amritsar                0.2979                0.0926
# 147           WB_Dakshin Dinajpur                0.2986                0.1326
# 148             CT_Janjgir Champa                0.2986                0.0939
# 149                  BR_Begusarai                0.2989                0.0503
# 150                 PB_Tarn Taran                0.2994                0.0705
# 151                     CT_Raipur                0.2998                0.1166
# 152                    TN_Madurai                0.2999                0.0820
# 153                      UP_Banda                0.3002                0.0377
# 154                     JH_Palamu                0.3008                0.0703
# 155                      MH_Dhule                0.3013                0.1086
# 156                       HR_Jind                0.3014                0.0811
# 157                      BR_Buxar                0.3015                0.0582
# 158                   UP_Fatehpur                0.3023                0.0474
# 159                   UP_Pilibhit                0.3025                0.0514
# 160                     MH_Nashik                0.3028                0.1079
# 161               TN_Nagapattinam                0.3028                0.0530
# 162                   UP_Bareilly                0.3032                0.0663
# 163                      TN_Theni                0.3034                0.0669
# 164                      JH_Pakur                0.3036                0.0567
# 165                     UP_Bijnor                0.3041                0.0522
# 166             TN_Tiruvannamalai                0.3043                0.0470
# 167               UP_Kanpur Nagar                0.3043                0.0806
# 168              OR_Jagatsinghpur                0.3050                0.1280
# 169                    HR_Bhiwani                0.3056                0.0845
# 170                  MH_Ratnagiri                0.3068                0.1318
# 171            ML_West Garo Hills                0.3070                0.0831
# 172            AR_Lower Subansiri                0.3073                0.1200
# 173                 MH_Gadchiroli                0.3076                0.0823
# 174                       PB_Moga                0.3077                0.0733
# 175          WB_South 24 Parganas                0.3086                0.1211
# 176                      JH_Gumla                0.3090                0.0775
# 177                      MH_Jalna                0.3097                0.1033
# 178        JH_Saraikela-Kharsawan                0.3099                0.0792
# 179                  BR_Jehanabad                0.3104                0.0595
# 180                      BR_Banka                0.3108                0.0491
# 181                    WB_Hooghly                0.3108                0.1399
# 182                    UP_Hathras                0.3108                0.0551
# 183                  AS_Karimganj                0.3121                0.0628
# 184                   UP_Ghazipur                0.3121                0.0389
# 185                    UP_Bhadohi                0.3130                0.0515
# 186                     JH_Chatra                0.3137                0.0543
# 187                     WB_Howrah                0.3141                0.1177
# 188                      MH_Thane                0.3142                0.1209
# 189                   UP_Lalitpur                0.3149                0.0335
# 190                  JH_Lohardaga                0.3150                0.0726
# 191                     JH_Khunti                0.3155                0.1028
# 192                     BR_Purnia                0.3157                0.0785
# 193                 BR_Sheikhpura                0.3161                0.0575
# 194                    OR_Bargarh                0.3171                0.0884
# 195           DL_North West Delhi                0.3176                0.1233
# 196                    BR_Nalanda                0.3176                0.0722
# 197                     UP_Jalaun                0.3176                0.0477
# 198             BR_East Champaran                0.3184                0.0554
# 199                    PB_Barnala                0.3190                0.0852
# 200                 MH_Aurangabad                0.3196                0.1059
# 201                 UP_Saharanpur                0.3198                0.0740
# 202                    CT_Bijapur                0.3201                0.1180
# 203                  BR_Darbhanga                0.3216                0.0625
# 204                   GJ_Junagadh                0.3217                0.1168
# 205                  UP_Balrampur                0.3218                0.0637
# 206                     ML_Ribhoi                0.3226                0.0833
# 207                      BR_Saran                0.3230                0.0668
# 208                 UP_Chitrakoot                0.3232                0.0307
# 209                       UP_Agra                0.3244                0.0696
# 210                    BR_Sheohar                0.3249                0.0728
# 211                 TN_Thiruvarur                0.3262                0.0563
# 212                  TN_Sivaganga                0.3267                0.0574
# 213                 CT_Kabeerdham                0.3270                0.0852
# 214                    UP_Mathura                0.3275                0.0742
# 215                     JH_Ranchi                0.3280                0.1105
# 216                   TN_Dindigul                0.3284                0.0730
# 217                   OR_Balasore                0.3286                0.1252
# 218                    MN_Thoubal                0.3288                0.0778
# 219                TN_Pudukkottai                0.3295                0.0540
# 220             TN_Ramanathapuram                0.3305                0.0625
# 221                      JH_Godda                0.3306                0.0624
# 222                 TN_Dharmapuri                0.3327                0.0626
# 223                GJ_Sabarkantha                0.3329                0.1096
# 224                   UP_Bahraich                0.3336                0.0479
# 225                   HP_Hamirpur                0.3349                0.1345
# 226                      OR_Angul                0.3357                0.0783
# 227                    CT_Jashpur                0.3359                0.0922
# 228                     OR_Jajpur                0.3362                0.0921
# 229                      UP_Basti                0.3365                0.0525
# 230                      BR_Siwan                0.3366                0.0684
# 231                      JH_Dumka                0.3369                0.0777
# 232             UP_Siddharthnagar                0.3379                0.0480
# 233                TG_Ranga Reddy                0.3379                0.1215
# 234                  UP_Ghaziabad                0.3390                0.0907
# 235                 NL_Mokokchung                0.3392                0.1287
# 236                    MP_Sheopur                0.3399                0.0549
# 237                  UP_Shrawasti                0.3408                0.0408
# 238                   AS_Sonitpur                0.3419                0.0885
# 239                  OR_Kalahandi                0.3419                0.0913
# 240                 JH_Hazaribagh                0.3421                0.0783
# 241              TR_South Tripura                0.3421                0.1365
# 242                  UP_Gorakhpur                0.3423                0.0757
# 243                 GJ_Panchmahal                0.3427                0.1163
# 244                UP_Bulandshahr                0.3439                0.0606
# 245                      TN_Karur                0.3463                0.0705
# 246                      UP_Gonda                0.3463                0.0520
# 247                 OR_Malkangiri                0.3469                0.0667
# 248            TN_Tiruchirappalli                0.3474                0.0886
# 249                 MH_Chandrapur                0.3476                0.1054
# 250                    WB_Birbhum                0.3484                0.1258
# 251        CT_Uttar Bastar Kanker                0.3489                0.1080
# 252                  BR_Bhagalpur                0.3490                0.0716
# 253                   PB_Faridkot                0.3499                0.1140
# 254                     BR_Munger                0.3506                0.0626
# 255               OR_Nabarangapur                0.3509                0.0641
# 256                    CT_Raigarh                0.3523                0.1181
# 257          PB_Sri Muktsar Sahib                0.3527                0.0786
# 258                    KA_Raichur                0.3535                0.0942
# 259                   UP_Mirzapur                0.3548                0.0567
# 260               TN_Virudhunagar                0.3558                0.0892
# 261                    JH_Jamtara                0.3560                0.0834
# 262                     UP_Jhansi                0.3562                0.0752
# 263                  MZ_Lawngtlai                0.3573                0.1008
# 264           ML_East Khasi Hills                0.3586                0.1218
# 265                   AS_Udalguri                0.3594                0.0649
# 266                 TN_Perambalur                0.3594                0.0760
# 267                     MH_Washim                0.3601                0.1470
# 268                    JH_Ramgarh                0.3603                0.0907
# 269                   MP_Shajapur                0.3604                0.0663
# 270                  AS_Sivasagar                0.3604                0.0714
# 271                 PB_Kapurthala                0.3604                0.1197
# 272                    PB_Patiala                0.3606                0.1146
# 273                  OR_Kandhamal                0.3609                0.0869
# 274            WB_Purba Medinipur                0.3613                0.1637
# 275                     AS_Cachar                0.3623                0.0723
# 276                DL_South Delhi                0.3624                0.1492
# 277                      CT_Korba                0.3626                0.1166
# 278                      HR_Hisar                0.3627                0.0984
# 279                    JH_Simdega                0.3630                0.0694
# 280                  OR_Kendujhar                0.3641                0.0792
# 281                      TN_Salem                0.3643                0.0918
# 282              MN_Churachandpur                0.3654                0.1105
# 283                   UP_Varanasi                0.3661                0.1004
# 284                     NL_Kohima                0.3696                0.1161
# 285                    AP_Kurnool                0.3735                0.1582
# 286                TN_Krishnagiri                0.3746                0.0795
# 287                    OR_Cuttack                0.3750                0.1297
# 288                 KA_Davanagere                0.3758                0.1065
# 289                    HR_Kaithal                0.3768                0.1019
# 290                 OR_Sundargarh                0.3795                0.1070
# 291          WB_North 24 Parganas                0.3796                0.1319
# 292                   TN_Namakkal                0.3799                0.0883
# 293                      OR_Boudh                0.3804                0.0722
# 294                       GJ_Dang                0.3840                0.0905
# 295                TN_Kanyakumari                0.3841                0.0853
# 296                  MP_Alirajpur                0.3841                0.0575
# 297                     HR_Palwal                0.3842                0.0971
# 298               TR_West Tripura                0.3847                0.1792
# 299                   OR_Balangir                0.3874                0.0616
# 300                      AS_Baksa                0.3888                0.0550
# 301                   OR_Nayagarh                0.3889                0.0967
# 302                     KA_Yadgir                0.3896                0.1266
# 303                 DL_West Delhi                0.3898                0.1736
# 304                     UP_Meerut                0.3906                0.1163
# 305            PB_Fatehgarh Sahib                0.3907                0.0933
# 306                  AS_Kokrajhar                0.3910                0.0711
# 307                   AS_Goalpara                0.3920                0.0660
# 308                  OR_Dhenkanal                0.3924                0.0877
# 309                    HR_Panipat                0.3928                0.1197
# 310                      MP_Satna                0.3946                0.0855
# 311                 OR_Kendrapara                0.3946                0.1123
# 312                      BR_Arwal                0.3953                0.0516
# 313                   NL_Longleng                0.3963                0.1528
# 314                    AS_Barpeta                0.3987                0.0984
# 315              TR_North Tripura                0.3992                0.1303
# 316                   AS_Tinsukia                0.3995                0.0785
# 317                   OR_Gajapati                0.3997                0.0853
# 318                  GJ_Bhavnagar                0.4023                0.1382
# 319                   GJ_Jamnagar                0.4028                0.1467
# 320                  AP_Anantapur                0.4029                0.1909
# 321                   PB_Rupnagar                0.4045                0.1042
# 322                     MP_Jhabua                0.4046                0.0635
# 323             JH_East Singhbhum                0.4047                0.1431
# 324                     UP_Mahoba                0.4054                0.0707
# 325                    UP_Baghpat                0.4058                0.0902
# 326                      TN_Erode                0.4062                0.0772
# 327                HR_Yamunanagar                0.4081                0.1544
# 328                  RJ_Bharatpur                0.4100                0.1121
# 329                 AS_Dima Hasao                0.4112                0.1186
# 330                      HR_Sirsa                0.4115                0.1200
# 331                      MP_Sidhi                0.4132                0.0550
# 332                 MH_Sindhudurg                0.4141                0.1909
# 333                     AP_Guntur                0.4180                0.1562
# 334                      KA_Gadag                0.4184                0.1538
# 335                   AP_Prakasam                0.4187                0.2005
# 336                     HR_Rohtak                0.4192                0.1387
# 337                      MP_Bhind                0.4198                0.0762
# 338              AP_East Godavari                0.4199                0.1378
# 339                   PB_Ludhiana                0.4205                0.1417
# 340                    AS_Darrang                0.4225                0.0803
# 341                   JK_Anantnag                0.4227                0.1040
# 342                     MH_Wardha                0.4232                0.1388
# 343                     KA_Koppal                0.4235                0.1355
# 344                   OR_Rayagada                0.4235                0.0824
# 345                    OR_Bhadrak                0.4240                0.0940
# 346                    AS_Chirang                0.4241                0.0816
# 347                    MP_Barwani                0.4241                0.0586
# 348                  HR_Fatehabad                0.4241                0.1143
# 349                      KA_Bidar                0.4251                0.1292
# 350                    JH_Koderma                0.4252                0.0860
# 351                   MH_Kolhapur                0.4267                0.2025
# 352                       OR_Puri                0.4272                0.1242
# 353                       MP_Dhar                0.4278                0.0791
# 354              AP_Y.S.R. Kadapa                0.4278                0.1932
# 355                  MP_Singrauli                0.4292                0.0653
# 356                     KA_Haveri                0.4307                0.0889
# 357                    UP_Lucknow                0.4308                0.1571
# 358                HR_Kurukshetra                0.4309                0.1438
# 359                KA_Chitradurga                0.4317                0.1818
# 360  PB_Shahid Bhagat Singh Nagar                0.4325                0.1481
# 361                     MH_Satara                0.4340                0.1807
# 362                     RJ_Jalore                0.4340                0.1078
# 363                   CT_Dhamtari                0.4343                0.1373
# 364                   MP_Shivpuri                0.4346                0.0694
# 365                  KA_Bagalkote                0.4350                0.1243
# 366                   TN_Tiruppur                0.4351                0.0794
# 367                  RJ_Dungarpur                0.4353                0.1153
# 368                     RJ_Barmer                0.4379                0.1324
# 369                 DL_East Delhi                0.4386                0.1731
# 370                     MP_Morena                0.4390                0.0835
# 371                     HR_Karnal                0.4398                0.1577
# 372                    RJ_Karauli                0.4430                0.1185
# 373                    OR_Koraput                0.4430                0.1176
# 374                    RJ_Udaipur                0.4439                0.1421
# 375                   AS_Morigaon                0.4464                0.0732
# 376                   JK_Srinagar                0.4468                0.1233
# 377                   MP_Khargone                0.4471                0.0776
# 378                  PB_Jalandhar                0.4491                0.1633
# 379                     RJ_Sirohi                0.4503                0.1570
# 380               HR_Mahendragarh                0.4513                0.1480
# 381                     OR_Ganjam                0.4514                0.2212
# 382                 AP_Srikakulam                0.4517                0.1563
# 383                       MP_Rewa                0.4519                0.0966
# 384                     MH_Sangli                0.4524                0.1741
# 385                     MP_Mandla                0.4538                0.0657
# 386                 OR_Subarnapur                0.4538                0.0929
# 387                    KA_Ballari                0.4547                0.1530
# 388                   KA_Tumakuru                0.4552                0.1366
# 389                 KA_Shivamogga                0.4580                0.1516
# 390               AP_Vizianagaram                0.4587                0.1520
# 391                    AS_Nalbari                0.4590                0.0856
# 392                     HR_Rewari                0.4595                0.1765
# 393             RJ_Sawai Madhopur                0.4597                0.1280
# 394                   AP_Chittoor                0.4621                0.2001
# 395                    AP_Krishna                0.4622                0.1660
# 396                    RJ_Dholpur                0.4640                0.1307
# 397                     JK_Budgam                0.4641                0.1519
# 398                      GJ_Kheda                0.4643                0.1456
# 399                  JK_Bandipora                0.4646                0.1180
# 400                    JK_Kupwara                0.4651                0.0826
# 401                      GJ_Dahod                0.4659                0.1809
# 402                   RJ_Banswara                0.4662                0.1347
# 403                      RJ_Dausa                0.4663                0.1045
# 404                      MP_Katni                0.4667                0.0823
# 405           DL_South West Delhi                0.4684                0.1915
# 406             AP_S.P.S. Nellore                0.4694                0.2263
# 407                     MH_Gondia                0.4711                0.1313
# 408                   JK_Kishtwar                0.4714                0.1468
# 409                 CT_Mahasamund                0.4720                0.1468
# 410                      RJ_Baran                0.4742                0.1246
# 411                    OR_Deogarh                0.4743                0.0837
# 412                      RJ_Alwar                0.4746                0.1689
# 413                     MP_Umaria                0.4759                0.0703
# 414                    HR_Sonipat                0.4775                0.1605
# 415             KA_Chikkamagaluru                0.4779                0.1758
# 416                  RJ_Jaisalmer                0.4792                0.1425
# 417                      MP_Panna                0.4794                0.0498
# 418                     MH_Nagpur                0.4798                0.1746
# 419                 KL_Malappuram                0.4799                0.1592
# 420                CT_Rajnandgaon                0.4800                0.1320
# 421                 RJ_Ganganagar                0.4804                0.1626
# 422            KA_Chikkaballapura                0.4805                0.1691
# 423                 MP_Chhatarpur                0.4810                0.0731
# 424                       RJ_Pali                0.4812                0.1507
# 425                     GJ_Amreli                0.4814                0.1640
# 426                  RJ_Rajsamand                0.4819                0.1291
# 427                    KA_Dharwad                0.4821                0.1349
# 428                 WB_Darjeeling                0.4831                0.1803
# 429                   RJ_Bhilwara                0.4840                0.1468
# 430                      BR_Patna                0.4842                0.1850
# 431                       GJ_Tapi                0.4843                0.1598
# 432                  MP_Tikamgarh                0.4893                0.0847
# 433                      MZ_Mamit                0.4899                0.1625
# 434                    HR_Jhajjar                0.4904                0.1410
# 435              GJ_Surendranagar                0.4914                0.1060
# 436                      RJ_Bundi                0.4916                0.1692
# 437                    RJ_Bikaner                0.4924                0.1826
# 438                     GJ_Rajkot                0.4927                0.1696
# 439                      KA_Kolar                0.4928                0.1716
# 440                    RJ_Jodhpur                0.4940                0.1779
# 441                      GJ_Patan                0.4959                0.1615
# 442                    JK_Pulwama                0.4969                0.1472
# 443                    JK_Rajouri                0.4971                0.1093
# 444                      PY_Yanam                0.4971                0.1127
# 445                   PY_Karaikal                0.4976                0.1135
# 446        AR_Upper Dibang Valley                0.4985                0.1683
# 447                 AS_Bongaigaon                0.4988                0.0952
# 448                 MP_Ashoknagar                0.4989                0.0852
# 449                AR_Upper Siang                0.4991                0.1916
# 450                 MP_Chhindwara                0.5000                0.0918
# 451                 AS_Hailakandi                0.5000                0.0875
# 452              AP_West Godavari                0.5022                0.1588
# 453                    MP_Anuppur                0.5026                0.0752
# 454                   MP_Balaghat                0.5045                0.0925
# 455                     RJ_Nagaur                0.5045                0.1892
# 456                 PY_Puducherry                0.5055                0.1489
# 457                RJ_Hanumangarh                0.5065                0.1627
# 458                  JK_Ganderbal                0.5076                0.1584
# 459                       MP_Guna                0.5078                0.0818
# 460                      MP_Damoh                0.5100                0.0913
# 461                    AS_Dhemaji                0.5103                0.1149
# 462                       RJ_Tonk                0.5105                0.1498
# 463                     KA_Hassan                0.5106                0.1607
# 464                  JK_Baramulla                0.5108                0.1399
# 465                     MP_Raisen                0.5115                0.0828
# 466                      MP_Seoni                0.5136                0.0907
# 467                    MP_Vidisha                0.5150                0.0940
# 468                   MH_Bhandara                0.5152                0.1489
# 469                   JK_Shopiyan                0.5162                0.1780
# 470                     AS_Kamrup                0.5166                0.1281
# 471                     RJ_Jaipur                0.5167                0.1883
# 472                      MP_Betul                0.5168                0.1058
# 473                     KA_Mandya                0.5178                0.1472
# 474                RJ_Chittorgarh                0.5178                0.1503
# 475                      JK_Jammu                0.5198                0.2460
# 476                 OR_Jharsuguda                0.5210                0.1347
# 477                 AR_East Siang                0.5221                0.1782
# 478                 PB_Hoshiarpur                0.5224                0.1902
# 479            KA_Chamarajanagara                0.5234                0.1422
# 480                      MP_Sagar                0.5250                0.1324
# 481                      RJ_Churu                0.5251                0.1486
# 482                  MN_Bishnupur                0.5254                0.1106
# 483                      AR_Anjaw                0.5266                0.1384
# 484                    OR_Nuapada                0.5267                0.0784
# 485                    MP_Khandwa                0.5268                0.0945
# 486                  AS_Lakhimpur                0.5296                0.0950
# 487                MN_Imphal East                0.5296                0.1613
# 488                      GJ_Kutch                0.5305                0.1553
# 489                    GJ_Mehsana                0.5310                0.2034
# 490              AP_Visakhapatnam                0.5310                0.1861
# 491                   GJ_Vadodara                0.5311                0.2044
# 492                   KL_Palakkad                0.5314                0.1752
# 493                  AS_Dibrugarh                0.5341                0.1343
# 494                  MP_Burhanpur                0.5378                0.1379
# 495              UT_Pauri Garhwal                0.5406                0.2100
# 496                   AS_Golaghat                0.5415                0.1012
# 497                  AR_Changlang                0.5452                0.1440
# 498                   MP_Mandsaur                0.5473                0.0896
# 499                     UT_Almora                0.5482                0.2149
# 500                    MZ_Kolasib                0.5483                0.1942
# 501                    MZ_Lunglei                0.5485                0.2076
# 502                GJ_Banaskantha                0.5502                0.2167
# 503                      MP_Dewas                0.5514                0.1021
# 504             KA_Uttara Kannada                0.5514                0.1686
# 505                    MP_Dindori                0.5517                0.0860
# 506              UT_Tehri Garhwal                0.5528                0.1886
# 507                     JK_Kathua                0.5535                0.1686
# 508                 KA_Ramanagara                0.5540                0.2233
# 509                MP_Hoshangabad                0.5541                0.1173
# 510                     KA_Mysuru                0.5546                0.2057
# 511                 RJ_Pratapgarh                0.5563                0.1319
# 512                     AS_Jorhat                0.5569                0.1074
# 513                  OR_Sambalpur                0.5575                0.1490
# 514                    MP_Gwalior                0.5581                0.1693
# 515                      MP_Datia                0.5581                0.0992
# 516                    MP_Rajgarh                0.5583                0.0959
# 517                UT_Pithoragarh                0.5597                0.1911
# 518                     JK_Kulgam                0.5633                0.1723
# 519                      RJ_Sikar                0.5646                0.1976
# 520                     MP_Ratlam                0.5652                0.1123
# 521                 TN_Coimbatore                0.5664                0.1437
# 522                   MZ_Champhai                0.5671                0.2057
# 523                     AR_Tawang                0.5678                0.2310
# 524                       JK_Doda                0.5689                0.1239
# 525                  RJ_Jhunjhunu                0.5690                0.2015
# 526                    GJ_Navsari                0.5693                0.2014
# 527        AR_Lower Dibang Valley                0.5695                0.1673
# 528                MN_Imphal West                0.5699                0.1752
# 529                    GJ_Narmada                0.5706                0.2535
# 530                     KA_Kodagu                0.5741                0.2140
# 531           KA_Dakshina Kannada                0.5771                0.1859
# 532                       RJ_Kota                0.5772                0.2132
# 533                      RJ_Ajmer                0.5775                0.2054
# 534                      JK_Punch                0.5799                0.1171
# 535                   RJ_Jhalawar                0.5801                0.1387
# 536                MP_Narsinghpur                0.5801                0.1043
# 537                      GJ_Anand                0.5805                0.1739
# 538                     GJ_Valsad                0.5808                0.1756
# 539                   JK_Udhampur                0.5827                0.1767
# 540                   MP_Jabalpur                0.5829                0.1875
# 541                    MP_Shahdol                0.5831                0.1228
# 542                      MZ_Saiha                0.5923                0.1617
# 543                     LA_Kargil                0.5952                0.2886
# 544                   TN_Nilgiris                0.5967                0.1774
# 545                  KL_Kozhikode                0.6010                0.2203
# 546                      JK_Reasi                0.6115                0.1358
# 547                  KL_Kasaragod                0.6117                0.2598
# 548                      GJ_Surat                0.6119                0.1922
# 549                    MP_Neemuch                0.6145                0.1278
# 550                    GJ_Bharuch                0.6175                0.1768
# 551                  GJ_Porbandar                0.6187                0.2381
# 552                     MP_Sehore                0.6193                0.1364
# 553                  GJ_Ahmedabad                0.6213                0.2129
# 554                     JK_Ramban                0.6219                0.1986
# 555                   MZ_Serchhip                0.6286                0.2469
# 556                    NL_Dimapur                0.6302                0.1549
# 557                       MH_Pune                0.6306                0.2334
# 558                   UT_Haridwar                0.6312                0.1430
# 559                     KL_Kannur                0.6314                0.2311
# 560                AR_West Kameng                0.6329                0.1947
# 561                     KL_Kollam                0.6335                0.2273
# 562                      MP_Harda                0.6343                0.1145
# 563          UT_Udham Singh Nagar                0.6343                0.1344
# 564                  KL_Alappuzha                0.6385                0.2430
# 565                   KL_Thrissur                0.6387                0.2301
# 566                    UT_Chamoli                0.6435                0.2753
# 567                     HR_Ambala                0.6460                0.2809
# 568                      KA_Udupi                0.6463                0.2429
# 569                     MP_Ujjain                0.6478                0.1851
# 570                  HR_Faridabad                0.6479                0.2130
# 571                  UT_Champawat                0.6591                0.2396
# 572                   UT_Nainital                0.6604                0.2230
# 573                     HP_Chamba                0.6644                0.1955
# 574                 UT_Uttarkashi                0.6674                0.2499
# 575                   KL_Kottayam                0.6681                0.2541
# 576                     TR_Dhalai                0.6724                0.1737
# 577                  HR_Panchkula                0.6777                0.2871
# 578                  GA_North Goa                0.6782                0.2433
# 579                UT_Rudraprayag                0.6786                0.2230
# 580              AN_South Andaman                0.6800                0.2786
# 581                      JK_Samba                0.6819                0.2233
# 582                     KL_Idukki                0.6848                0.2430
# 583                  UT_Bageshwar                0.6863                0.2604
# 584   AN_North and Middle Andaman                0.6941                0.2948
# 585         KL_Thiruvananthapuram                0.6945                0.2734
# 586                    OR_Khordha                0.7051                0.4857
# 587                  TG_Hyderabad                0.7054                0.2599
# 588               PB_S.A.S. Nagar                0.7155                0.2533
# 589                GJ_Gandhinagar                0.7249                0.2318
# 590                     MP_Bhopal                0.7272                0.2644
# 591                 AR_Papum Pare                0.7289                0.2979
# 592                        DN_Diu                0.7333                0.3710
# 593               SK_North Sikkim                0.7342                0.2271
# 594                SK_West Sikkim                0.7369                0.2381
# 595                    HP_Sirmaur                0.7537                0.1718
# 596                      HP_Mandi                0.7564                0.2641
# 597                    TN_Chennai                0.7564                0.3162
# 598                     HP_Kangra                0.7630                0.2594
# 599                     MZ_Aizawl                0.7635                0.2765
# 600                      HP_Kullu                0.7640                0.2241
# 601                 CH_Chandigarh                0.7647                0.2922
# 602                   UT_Dehradun                0.7681                0.2740
# 603                       PY_Mahe                0.7684                0.3634
# 604                    KL_Wayanad                0.7716                0.3068
# 605                  KL_Ernakulam                0.7777                0.2641
# 606                     HP_Shimla                0.7813                0.2622
# 607               SK_South Sikkim                0.8032                0.2559
# 608                        HP_Una                0.8097                0.2745
# 609                LD_Lakshadweep                0.8158                0.3693
# 610                   HP_Bilaspur                0.8198                0.2885
# 611                        LA_Leh                0.8232                0.4596
# 612             KL_Pathanamthitta                0.8317                0.3591
# 613                   UP_Hamirpur                0.8549                0.1371
# 614                     MP_Indore                0.8572                0.3041
# 615        AS_Kamrup Metropolitan                0.8885                0.3516
# 616                    HP_Kinnaur                0.8946                0.3103
# 617                SK_East Sikkim                0.9016                0.3085
# 618                DL_North Delhi                0.9092                0.3039
# 619                    WB_Kolkata                0.9202                0.3569
# 620        UP_Gautam Buddha Nagar                0.9457                0.3010
# 621                  GA_South Goa                0.9546                0.3455
# 622           HP_Lahaul and Spiti                0.9595                0.2992
# 623                   HR_Gurugram                1.1256                0.4603
# 624                      DN_Daman                1.1283                0.3038
# 625                      HP_Solan                1.1359                0.2621
# 626              DL_Central Delhi                1.6223                0.6073
# 627                   CT_Bilaspur                1.7064                0.6314
# 628                     MH_Mumbai                2.3042                0.8557
# 629                  DL_New Delhi                5.1546                2.5670

# %% [markdown]
# #### So finally saving ratios calculated at district level  as "district-vaccinated-dose-ratio.csv" :-

# %%
district_wise_data.to_csv('district-vaccinated-dose-ratio.csv', index=False)

# %% [markdown]
# ## Calculating ratios at state level :-

# %%
State_wise_data = Final_data.copy()
State_wise_data = State_wise_data.drop(columns=["District","District_Key"])
# State_wise_data

# %%
State_wise_data = State_wise_data.groupby(['State']).agg({'First Dose Administered':'sum',
                                                          'Second Dose Administered':'sum',
                                                          'TOT_P':'sum'}).reset_index()
# len(State_wise_data) is 36
# State_wise_data

# %%
State_wise_data['vaccinateddose1ratio'] = State_wise_data['First Dose Administered']/State_wise_data['TOT_P']
State_wise_data['vaccinateddose2ratio'] = State_wise_data['Second Dose Administered']/State_wise_data['TOT_P']
State_wise_data = State_wise_data.drop(columns=["First Dose Administered","Second Dose Administered","TOT_P"])
State_wise_data = State_wise_data.sort_values('vaccinateddose1ratio',ignore_index=True)

# %%
State_wise_data
# Out:
#                                        State  vaccinateddose1ratio  \
# 0                                  Telangana              0.227747
# 1                                  Meghalaya              0.272520
# 2                               Chhattisgarh              0.297575
# 3                              Uttar Pradesh              0.298460
# 4                                      Bihar              0.304197
# 5                                  Jharkhand              0.313263
# 6                                West Bengal              0.316549
# 7                                 Tamil Nadu              0.330243
# 8                                   Nagaland              0.331077
# 9                                    Manipur              0.346882
# 10                                    Punjab              0.349922
# 11                                    Odisha              0.402219
# 12                                   Tripura              0.406929
# 13                               Maharashtra              0.412534
# 14                                     Assam              0.415951
# 15                         Arunachal Pradesh              0.418216
# 16                            Andhra Pradesh              0.445081
# 17                                 Karnataka              0.476195
# 18                                     Delhi              0.480186
# 19                                   Haryana              0.483982
# 20                                 Rajasthan              0.494429
# 21                         Jammu and Kashmir              0.509526
# 22                                Puducherry              0.512671
# 23                                   Gujarat              0.515561
# 24                            Madhya Pradesh              0.522051
# 25                          Himachal Pradesh              0.570468
# 26                                   Mizoram              0.610891
# 27                                    Kerala              0.637204
# 28                               Uttarakhand              0.642907
# 29               Andaman and Nicobar Islands              0.684313
# 30                                    Ladakh              0.706138
# 31                                Chandigarh              0.764666
# 32                                       Goa              0.799571
# 33                               Lakshadweep              0.815814
# 34                                    Sikkim              0.829173
# 35  Dadra and Nagar Haveli and Daman and Diu              1.043725
#
#     vaccinateddose2ratio
# 0               0.077854
# 1               0.084954
# 2               0.100941
# 3               0.057177
# 4               0.060219
# 5               0.079232
# 6               0.123397
# 7               0.082706
# 8               0.102046
# 9               0.098972
# 10              0.110991
# 11              0.129194
# 12              0.159224
# 13              0.153050
# 14              0.091933
# 15              0.143317
# 16              0.173927
# 17              0.154087
# 18              0.191533
# 19              0.163662
# 20              0.159031
# 21              0.150640
# 22              0.148816
# 23              0.174302
# 24              0.112669
# 25              0.182683
# 26              0.216435
# 27              0.233657
# 28              0.201367
# 29              0.283608
# 30              0.371834
# 31              0.292186
# 32              0.288202
# 33              0.369348
# 34              0.274272
# 35              0.318207

# %% [markdown]
# #### So finally saving ratios calculated at state level  as "state-vaccinated-dose-ratio.csv" :-

# %%
State_wise_data.to_csv('state-vaccinated-dose-ratio.csv', index=False)

# %% [markdown]
# ## Calculating overall ratio :-

# %%
overall_data = pd.DataFrame()
overall_data['Country'] = ['India']
overall_data['vaccinateddose1ratio'] = Final_data['First Dose Administered'].sum()/Final_data['TOT_P'].sum()
overall_data['vaccinateddose2ratio'] = Final_data['Second Dose Administered'].sum()/Final_data['TOT_P'].sum()
overall_data
# Out:
#   Country  vaccinateddose1ratio  vaccinateddose2ratio
# 0   India              0.394204              0.117118

# %% [markdown]
# #### So finally saving overall ratio calculated as "overall-vaccinated-dose-ratio.csv" :-

# %%
overall_data.to_csv('overall-vaccinated-dose-ratio.csv', index=False)

# %% [markdown]
# # Q8 completed..:)
